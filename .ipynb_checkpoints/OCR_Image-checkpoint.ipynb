# %% [markdown]
# # OCR text identifier

# %% [markdown]
# ## * User needes install `Tesseract` and setup `Poppler` manually to the computer
#
# ## ** Create a folder called `images` and put all your images into the folder before run below

# %% [markdown]
# # Install Poppler
# ### Windows
# #### Windows users will have to install poppler for Windows, then add the bin/ folder to PATH.
# http://blog.alivate.com.au/poppler-windows/
#
# ### Mac
# #### Mac users will have to install poppler for Mac.
# http://macappstore.org/poppler/
#
#
# # Setup Pytesseract
#
# ## Download and install Tesseract to your computer
# * https://github.com/tesseract-ocr/tesseract/wiki
# * pip install pytesseract
#
# # Copy the installation path as shown as below
# tess.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
#
#
# # Install all dependencies
#
# #### ✔ OpenCV
# #### ✔ Numpy
# #### ✔ Pdf2Image
# #### ✔ Pillow
# ####  ✔ Pytesseract
#
# # Use `pip install -r requirements.txt`
#
# # Use `pip install -r requirements.txt`
#
# # run `python image_update.py`
#
# # run `ocr.py`
#
# # Results will be `OUTPUT` and  `LOGFILE` folders

# %%
import pdf2image
import os
from pdf2image import convert_from_path
import cv2

input_path = "./images/"
usable_image_path = "USABLE_IMAGES/"

try:
    os.mkdir(usable_image_path)
    print("Output File: {:s} has been created".format(usable_image_path))
except FileExistsError:
    print("File Already Exists...!")


imglist = os.listdir(input_path)
imageList = [(lambda x: input_path +x)(x) for x in imglist]


# convert pdf to png
def save_iamges(imglist, imageList, output_path):
    try:
        os.mkdir(output_path)
        print("Usable Images Output Folder: {:s} has been created\n".format(output_path))
    except FileExistsError:
        print("Folder Already Exists...!\n")

    pdf_count = 0
    img_count = 0
    falt_count = 0

    for i in range(len(imageList)):
        im_name = imglist[i]

        try:
            if imageList[i][-3:] == 'pdf':
                pdf_name = imglist[i][:-3] + "png"
                pdf_path = imageList[i]
                #         print(pdf_name)
                pages = convert_from_path(pdf_path)
                for page in pages:
                    page.save(output_path + pdf_name, "png")
                    pdf_count += 1
                print("Saved and converted {:s}  to {:s}".format(imglist[i], pdf_name))
                img_count +=1

            else:
                img = cv2.imread(imageList[i])
                print("Saved {:s}".format(im_name))
                cv2.imwrite(output_path + im_name, img)
                img_count += 1
        except:
            falt_count += 1
            print("{:s} is not a image or a pdf".format(imglist[i]))

    print("\n##############################################")
    print("Total {:d} images saved".format(img_count))
    print("Total {:d} pdf converted to image".format(pdf_count))
    print("Total {:d} is not an image or pdf".format(falt_count))
    print("################################################")

    imglist = os.listdir(output_path)
    imageList = [(lambda x: input_path + x)(x) for x in imglist]

    return imglist, imageList

save_iamges(imglist, imageList, output_path=usable_image_path)
# Out:
# File Already Exists...!
# Folder Already Exists...!
#
# Saved 1.webp
# Saved 10.jpg
# Saved 11.jpg
# Saved 12.jpg
# Saved 13.jpg
# Saved 14.jpg
# Saved 15.jpg
# Saved 16.jpg
# Saved 17.jpg
# Saved 18.jpg
# Saved 19.jpg
# Saved 2.webp
# Saved 20.jpg
# Saved 21.jpg
# Saved 22.jpg
# Saved 23.jpg
# Saved 24.jpg
# Saved 25.jpg
# Saved 26.jpg
# Saved 3.webp
# Saved 33.jpg
# Saved 339.jpg
# Saved 4.jpg
# Saved 5.jpg
# Saved 55.jpg
# Saved 6.jpg
# Saved 666.jpg
# Saved 7.jpg
# Saved 8.jpg
# Saved 9.jpg
# Saved and converted New Doc 2020-03-08 18.14.13.pdf  to New Doc 2020-03-08 18.14.13.png
# Saved and converted NZNS000001.pdf  to NZNS000001.png
# Saved and converted NZNS000002.pdf  to NZNS000002.png
# Saved and converted NZNS000003.pdf  to NZNS000003.png
# Saved and converted NZNS000004.pdf  to NZNS000004.png
# Saved and converted NZNS000006.pdf  to NZNS000006.png
# Saved and converted NZNS000007.pdf  to NZNS000007.png
# Saved NZNS000009.jpg
# Saved NZNS000010.jpg
# Saved NZNS000011.jpg
# Saved NZNS000012.jpg
# Saved NZNS000013.jpg
# Saved NZNS000015.jpg
# Saved PHOTO-2018-03-27-09-47-03.jpg
# Saved PHOTO-2019-01-14-14-07-47.jpg
# Saved PHOTO-2019-01-29-10-12-21.jpg
# Saved PHOTO-2020-04-09-13-16-27.jpg
# Saved PHOTO-2020-04-16-17-18-24.jpg
# Saved PHOTO-2020-04-16-17-22-18.jpg
# Saved PHOTO-2020-04-16-17-22-19.jpg
# Saved PHOTO-2020-04-16-17-22-19_1.jpg
# Saved PHOTO-2020-04-16-17-22-20.jpg
# Saved PHOTO-2020-04-16-17-22-20_2.jpg
# Saved PHOTO-2020-04-16-17-22-21.jpg
# Saved PHOTO-2020-04-16-17-22-21_1.jpg
# Saved PHOTO-2020-04-16-17-22-22.jpg
# Saved PHOTO-2020-04-16-17-22-22_1.jpg
# Saved PHOTO-2020-04-16-17-22-23.jpg
# Saved PHOTO-2020-04-16-17-22-24.jpg
# Saved PHOTO-2020-04-16-17-22-24_1.jpg
# Saved sur036500.tif
# Saved sur036501.tif
# Saved sur036503.tif
# Saved sur036504.tif
# Saved sur036505.tif
# Saved sur036506.tif
# Saved sur036507.tif
# Saved sur036508.tif
# Saved sur036509.tif
# Saved sur036510.tif
# Saved sur036511.tif
# Saved sur036513.tif
# Saved sur036514.tif
# Saved sur036515.tif
# Saved sur036516.tif
# Saved sur036532.tif
# Saved sur036535.tif
# Saved sur036537.tif
# Saved sur036538.tif
# Saved xz
# xz is not a image or a pdf
#
# ##############################################
# Total 79 images saved
# Total 8 pdf converted to image
# Total 1 is not an image or pdf
# ################################################
# (['1.webp',
#   '10.jpg',
#   '11.jpg',
#   '12.jpg',
#   '13.jpg',
#   '14.jpg',
#   '15.jpg',
#   '16.jpg',
#   '17.jpg',
#   '18.jpg',
#   '19.jpg',
#   '2.webp',
#   '20.jpg',
#   '21.jpg',
#   '22.jpg',
#   '23.jpg',
#   '24.jpg',
#   '25.jpg',
#   '26.jpg',
#   '3.webp',
#   '33.jpg',
#   '339.jpg',
#   '4.jpg',
#   '5.jpg',
#   '55.jpg',
#   '6.jpg',
#   '666.jpg',
#   '7.jpg',
#   '8.jpg',
#   '9.jpg',
#   'New Doc 2020-03-08 18.14.13.png',
#   'NZNS000001.png',
#   'NZNS000002.png',
#   'NZNS000003.png',
#   'NZNS000004.png',
#   'NZNS000006.png',
#   'NZNS000007.png',
#   'NZNS000009.jpg',
#   'NZNS000010.jpg',
#   'NZNS000011.jpg',
#   'NZNS000012.jpg',
#   'NZNS000013.jpg',
#   'NZNS000015.jpg',
#   'PHOTO-2018-03-27-09-47-03.jpg',
#   'PHOTO-2019-01-14-14-07-47.jpg',
#   'PHOTO-2019-01-29-10-12-21.jpg',
#   'PHOTO-2020-04-09-13-16-27.jpg',
#   'PHOTO-2020-04-16-17-18-24.jpg',
#   'PHOTO-2020-04-16-17-22-18.jpg',
#   'PHOTO-2020-04-16-17-22-19.jpg',
#   'PHOTO-2020-04-16-17-22-19_1.jpg',
#   'PHOTO-2020-04-16-17-22-20.jpg',
#   'PHOTO-2020-04-16-17-22-20_2.jpg',
#   'PHOTO-2020-04-16-17-22-21.jpg',
#   'PHOTO-2020-04-16-17-22-21_1.jpg',
#   'PHOTO-2020-04-16-17-22-22.jpg',
#   'PHOTO-2020-04-16-17-22-22_1.jpg',
#   'PHOTO-2020-04-16-17-22-23.jpg',
#   'PHOTO-2020-04-16-17-22-24.jpg',
#   'PHOTO-2020-04-16-17-22-24_1.jpg',
#   'sur036500.tif',
#   'sur036501.tif',
#   'sur036503.tif',
#   'sur036504.tif',
#   'sur036505.tif',
#   'sur036506.tif',
#   'sur036507.tif',
#   'sur036508.tif',
#   'sur036509.tif',
#   'sur036510.tif',
#   'sur036511.tif',
#   'sur036513.tif',
#   'sur036514.tif',
#   'sur036515.tif',
#   'sur036516.tif',
#   'sur036532.tif',
#   'sur036535.tif',
#   'sur036537.tif',
#   'sur036538.tif'],
#  ['./images/1.webp',
#   './images/10.jpg',
#   './images/11.jpg',
#   './images/12.jpg',
#   './images/13.jpg',
#   './images/14.jpg',
#   './images/15.jpg',
#   './images/16.jpg',
#   './images/17.jpg',
#   './images/18.jpg',
#   './images/19.jpg',
#   './images/2.webp',
#   './images/20.jpg',
#   './images/21.jpg',
#   './images/22.jpg',
#   './images/23.jpg',
#   './images/24.jpg',
#   './images/25.jpg',
#   './images/26.jpg',
#   './images/3.webp',
#   './images/33.jpg',
#   './images/339.jpg',
#   './images/4.jpg',
#   './images/5.jpg',
#   './images/55.jpg',
#   './images/6.jpg',
#   './images/666.jpg',
#   './images/7.jpg',
#   './images/8.jpg',
#   './images/9.jpg',
#   './images/New Doc 2020-03-08 18.14.13.png',
#   './images/NZNS000001.png',
#   './images/NZNS000002.png',
#   './images/NZNS000003.png',
#   './images/NZNS000004.png',
#   './images/NZNS000006.png',
#   './images/NZNS000007.png',
#   './images/NZNS000009.jpg',
#   './images/NZNS000010.jpg',
#   './images/NZNS000011.jpg',
#   './images/NZNS000012.jpg',
#   './images/NZNS000013.jpg',
#   './images/NZNS000015.jpg',
#   './images/PHOTO-2018-03-27-09-47-03.jpg',
#   './images/PHOTO-2019-01-14-14-07-47.jpg',
#   './images/PHOTO-2019-01-29-10-12-21.jpg',
#   './images/PHOTO-2020-04-09-13-16-27.jpg',
#   './images/PHOTO-2020-04-16-17-18-24.jpg',
#   './images/PHOTO-2020-04-16-17-22-18.jpg',
#   './images/PHOTO-2020-04-16-17-22-19.jpg',
#   './images/PHOTO-2020-04-16-17-22-19_1.jpg',
#   './images/PHOTO-2020-04-16-17-22-20.jpg',
#   './images/PHOTO-2020-04-16-17-22-20_2.jpg',
#   './images/PHOTO-2020-04-16-17-22-21.jpg',
#   './images/PHOTO-2020-04-16-17-22-21_1.jpg',
#   './images/PHOTO-2020-04-16-17-22-22.jpg',
#   './images/PHOTO-2020-04-16-17-22-22_1.jpg',
#   './images/PHOTO-2020-04-16-17-22-23.jpg',
#   './images/PHOTO-2020-04-16-17-22-24.jpg',
#   './images/PHOTO-2020-04-16-17-22-24_1.jpg',
#   './images/sur036500.tif',
#   './images/sur036501.tif',
#   './images/sur036503.tif',
#   './images/sur036504.tif',
#   './images/sur036505.tif',
#   './images/sur036506.tif',
#   './images/sur036507.tif',
#   './images/sur036508.tif',
#   './images/sur036509.tif',
#   './images/sur036510.tif',
#   './images/sur036511.tif',
#   './images/sur036513.tif',
#   './images/sur036514.tif',
#   './images/sur036515.tif',
#   './images/sur036516.tif',
#   './images/sur036532.tif',
#   './images/sur036535.tif',
#   './images/sur036537.tif',
#   './images/sur036538.tif'])

# %%
import pytesseract as tess
import datetime

tess.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %% [markdown]
# #### use above "USABLE_IMAGES" folder as input path below

# %%
input_path = "USABLE_IMAGES/"
logfile_path = "LOGFILE/"
output_path = "OUTPUT/"

try:
    os.mkdir(output_path)
    print("Output File: {:s} has been created".format(output_path))
except FileExistsError:
    print("File Already Exists...!")

try:
    os.mkdir(logfile_path)
    print("Output File: {:s} has been created".format(logfile_path))
except FileExistsError:
    print("File Already Exists...!")
# Out:
# Output File: OUTPUT/ has been created
# Output File: LOGFILE/ has been created

# %%
imglist = os.listdir(input_path)
imageList = [(lambda x: input_path +x)(x) for x in imglist]

# %%
logfile = open(logfile_path + "logfile.txt", 'w+')
logfile.write("Name,path,date,time\n")
all_list = []

print("################# OCR STARTED #######################################")

for i in range(len(imageList)):

    word_list = []
    name = imglist[i].split(".")[0]
    serial_number = "Serial Number = Not Recognized!"
    img = cv2.imread(imageList[i])
    text = tess.image_to_string(img)
    t = text.replace('\r', ' ')
    text_line = t.splitlines()

    start = 100
    end = None

    for line in range(len(text_line)):
        word = text_line[line]
        word_split = word.split("-")

        if "EASTING" in word or "LINE" in word or "NORTHING" in word or "DIST" in word:
            if start > line:
                start = line

        if "AREA=" in word or "AREA =" in word:
            end = line
            REAL = word.split(" ")[0:5]
            separator = ' '
            separator.join(REAL)
            word_list.append(separator.join(REAL))

            if start == None:
                for te in range(len(text_line)):
                    try:
                        if len(str(int(float(text_line[te].split(" ")[0])))) == 6:
                            #                             word_list.append(text_line[te:line])
                            start = te
                            break
                    except:
                        continue

        if len(word_split) == 5:
            try:
                int(word[1])
                #                 print(word_split[0])
                serial_number = "Serial Number = {:s}".format(word.split(" ")[0])
                break
            except:
                serial_number = "Serial Number = Not Recognized!"

    word_list.insert(0, serial_number)

    separator = '\r'
    #     separator.join(all_list[2][2:])
    if (start != 100) and (end != None):
        #         print(separator.join(text_line[start:end]))
        word_list.extend(text_line[start:end])
    #         print(start, " and ", end)
    separator = '\n'

    file_name = output_path + name + ".txt"
    path = os.path.abspath(file_name)

    time = datetime.datetime.now().strftime("%d%m%Y, %H:%M%p")

    logfile.write(name + "," + path + "," + time + "\n\n")

    file = open(file_name, 'w+')

    print("{:s} : {:d} out of {:d} created..".format(path, i + 1, len(imageList)))

    try:
        file.write(separator.join(word_list))
    except:
        file.write(word_list)
    #     file.write(separator.join(word_list))
    file.close()
    #     print(word_list)
    all_list.append(word_list)
logfile.close()

print("################# OCR END #######################################")
# Out:
# ################# OCR STARTED #######################################
# C:\Users\PC\OCR\OCR_From_Image\output\ : 1 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 2 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 3 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 4 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 5 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 6 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 7 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 8 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 9 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 10 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 11 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 12 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 13 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 14 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 15 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 16 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 17 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 18 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 19 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 20 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 21 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 22 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 23 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 24 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 25 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 26 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 27 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 28 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 29 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 30 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 31 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 32 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 33 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 34 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 35 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 36 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 37 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 38 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 39 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 40 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 41 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 42 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 43 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 44 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 45 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 46 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 47 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 48 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 49 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 50 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 51 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 52 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 53 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 54 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 55 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 56 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 57 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 58 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 59 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 60 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 61 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 62 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 63 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 64 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 65 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 66 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 67 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 68 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 69 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 70 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 71 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 72 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 73 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 74 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 75 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 76 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 77 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 78 out of 79 created..
# C:\Users\PC\OCR\OCR_From_Image\output\ : 79 out of 79 created..
# ################# OCR END #######################################
