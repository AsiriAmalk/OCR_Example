# %% [markdown]
# # OCR text identifier

# %% [markdown]
# ## * User needes install `Tesseract` and setup `Poppler` manually to the computer
#
# ## ** Create a folder called `images` and put all your images into the folder before run below

# %% [markdown]
# # Install Poppler
# ### Windows
# #### Windows users will have to install poppler for Windows, then add the bin/ folder to PATH.
# http://blog.alivate.com.au/poppler-windows/
#
# ### Mac
# #### Mac users will have to install poppler for Mac.
# http://macappstore.org/poppler/
#
#
# # Setup Pytesseract
#
# ## Download and install Tesseract to your computer
# * https://github.com/tesseract-ocr/tesseract/wiki
# * pip install pytesseract
#
# # Copy the installation path as shown as below
# tess.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
#
#
# # Install all dependencies
#
# #### ✔ OpenCV
# #### ✔ Numpy
# #### ✔ Pdf2Image
# #### ✔ Pillow
# ####  ✔ Pytesseract
#
# # Use `pip install -r requirements.txt`
#
# # Use `pip install -r requirements.txt`
#
# # run `python image_update.py`
#
# # run `ocr.py`
#
# # Results will be `OUTPUT` and  `LOGFILE` folders

# %%
import pdf2image
import os
from pdf2image import convert_from_path
import cv2

input_path = "./Image test/"
usable_image_path = "USABLE_IMAGES_TEST/"

try:
    os.mkdir(usable_image_path)
    print("Output File: {:s} has been created".format(usable_image_path))
except FileExistsError:
    print("File Already Exists...!")


imglist = os.listdir(input_path)
imageList = [(lambda x: input_path +x)(x) for x in imglist]


# convert pdf to png
def save_iamges(imglist, imageList, output_path):
    try:
        os.mkdir(output_path)
        print("Usable Images Output Folder: {:s} has been created\n".format(output_path))
    except FileExistsError:
        print("Folder Already Exists...!\n")

    pdf_count = 0
    img_count = 0
    falt_count = 0

    for i in range(len(imageList)):
        im_name = imglist[i]

        try:
            if imageList[i][-3:] == 'pdf':
                pdf_name = imglist[i][:-3] + "png"
                pdf_path = imageList[i]
                #         print(pdf_name)
                pages = convert_from_path(pdf_path)
                for page in pages:
                    page.save(output_path + pdf_name, "png")
                    pdf_count += 1
                print("Saved and converted {:s}  to {:s}".format(imglist[i], pdf_name))
                img_count +=1

            else:
                img = cv2.imread(imageList[i])
                print("Saved {:s}".format(im_name))
                cv2.imwrite(output_path + im_name, img)
                img_count += 1
        except:
            falt_count += 1
            print("{:s} is not a image or a pdf".format(imglist[i]))

    print("\n##############################################")
    print("Total {:d} images saved".format(img_count))
    print("Total {:d} pdf converted to image".format(pdf_count))
    print("Total {:d} is not an image or pdf".format(falt_count))
    print("################################################")

    imglist = os.listdir(output_path)
    imageList = [(lambda x: input_path + x)(x) for x in imglist]

    return imglist, imageList

save_iamges(imglist, imageList, output_path=usable_image_path)
# Out:
# Output File: USABLE_IMAGES_TEST/ has been created
# Folder Already Exists...!
#
# Saved and converted 0_28.pdf  to 0_28.png
# Saved 3-04-378-01_03.tif
# Saved 3-04-378-01_04.tif
# Saved 3-04-378-01_05.tif
# Saved 3-04-378-01_06.tif
# Saved 3-04-378-01_07.tif
# Saved 3-04-378-01_08.tif
# Saved 3-04-378-01_09.tif
# Saved 3-04-378-01_10.tif
# Saved 3-04-378-01_11.tif
# Saved 3-04-378-01_12.tif
# Saved 3-04-378-01_13.tif
# Saved 3-04-378-01_14.tif
# Saved 3-04-378-01_15.tif
# Saved 3-04-378-01_16.tif
# Saved and converted Scanned31_139.pdf  to Scanned31_139.png
# Saved and converted Scanned31_140.pdf  to Scanned31_140.png
# Saved and converted Scanned31_141.pdf  to Scanned31_141.png
# Saved and converted Scanned31_142.pdf  to Scanned31_142.png
# Saved and converted Scanned31_143.pdf  to Scanned31_143.png
# Saved and converted Scanned31_144.pdf  to Scanned31_144.png
# Saved and converted Scanned31_145.pdf  to Scanned31_145.png
# Saved and converted Scanned31_146.pdf  to Scanned31_146.png
# Saved and converted Scanned31_147.pdf  to Scanned31_147.png
# Saved and converted Scanned36_0.pdf  to Scanned36_0.png
#
# ##############################################
# Total 183 images saved
# Total 42 pdf converted to image
# Total 0 is not an image or pdf
# ################################################
# (['0_28.png',
#   '3-04-378-01_03.tif',
#   '3-04-378-01_04.tif',
#   '3-04-378-01_05.tif',
#   '3-04-378-01_06.tif',
#   '3-04-378-01_07.tif',
#   '3-04-378-01_08.tif',
#   '3-04-378-01_09.tif',
#   '3-04-378-01_10.tif',
#   '3-04-378-01_11.tif',
#   '3-04-378-01_12.tif',
#   '3-04-378-01_13.tif',
#   '3-04-378-01_14.tif',
#   '3-04-378-01_15.tif',
#   '3-04-378-01_16.tif',
#   '3-04-378-01_17.tif',
#   '3-04-378-01_18.tif',
#   '3-04-378-01_19.tif',
#   '3-04-378-01_20.tif',
#   '3-04-378-01_21.tif',
#   '3-04-378-01_22.tif',
#   '3-04-378-01_23.tif',
#   '3-04-378-01_24.tif',
#   '3-04-378-01_25.tif',
#   '3-04-378-01_26.tif',
#   '3-04-378-01_27.tif',
#   '3-04-378-01_28.tif',
#   '3-04-378-01_29.tif',
#   '3-04-378-01_30.tif',
#   '3-04-378-01_31.tif',
#   '3-04-378-01_32.tif',
#   '3-04-378-01_33.tif',
#   '3-04-378-01_34.tif',
#   '3-04-378-01_35.tif',
#   '3-04-378-01_36.tif',
#   '3-04-378-01_37.tif',
#   '3-04-378-01_38.tif',
#   '3-04-378-01_39.tif',
#   '3-04-378-01_40.tif',
#   '3-04-378-01_41.tif',
#   '3-04-378-01_42.tif',
#   '3-04-378-01_43.tif',
#   '3-04-378-01_44.tif',
#   '3-04-378-01_45.tif',
#   '3-04-378-01_46.tif',
#   '3-04-378-01_47.tif',
#   '3-04-378-01_48.tif',
#   '3-04-378-01_49.tif',
#   '3-04-378-01_50.tif',
#   '3-04-378-01_51.tif',
#   '3-04-378-01_52.tif',
#   '3-04-378-01_53.tif',
#   '3-04-378-01_54.tif',
#   '3-04-378-01_55.tif',
#   '3-04-378-01_56.tif',
#   '3-04-378-01_57.tif',
#   '3-04-378-01_58.tif',
#   '3-04-378-01_59.tif',
#   '3-04-378-01_60.tif',
#   '3-04-378-01_61.tif',
#   '3-04-378-01_62.tif',
#   '3-04-378-01_63.tif',
#   '3-04-378-01_64.tif',
#   '3-04-378-01_65.tif',
#   '3-04-378-01_66.tif',
#   '3-04-378-01_67.tif',
#   '3-04-378-01_68.tif',
#   '3-04-401-01_01.tif',
#   '3-04-401-01_02.tif',
#   '3-04-401-01_03.tif',
#   '3-04-401-01_04.tif',
#   '3-04-401-01_05.tif',
#   '3-04-401-01_06.tif',
#   '3-04-401-01_07.tif',
#   '3-04-401-01_08.tif',
#   '3-04-401-01_09.tif',
#   '3-04-401-01_10.tif',
#   '3-04-401-01_11.tif',
#   '3-04-401-01_12.tif',
#   '3-04-401-01_13.tif',
#   '3-04-401-01_14.tif',
#   '3-04-401-01_15.tif',
#   '3-04-401-01_16.tif',
#   '3-04-401-01_17.tif',
#   '3-04-401-01_18.tif',
#   '3-04-401-01_19.tif',
#   '3-04-401-01_20.tif',
#   '3-04-401-01_21.tif',
#   '3-04-401-01_22.tif',
#   '3-04-401-01_23.tif',
#   '3-04-401-01_24.tif',
#   '3-04-401-01_25.tif',
#   '3-04-401-01_26.tif',
#   '3-04-401-01_27.tif',
#   '3-04-401-01_28.tif',
#   '3-04-401-01_29.tif',
#   '3-04-401-01_30.tif',
#   '3-04-401-01_31.tif',
#   '3-04-401-01_32.tif',
#   '3-04-401-01_33.tif',
#   '3-04-401-01_34.tif',
#   '3-04-401-01_35.tif',
#   '3-04-401-01_36.tif',
#   '3-04-401-01_37.tif',
#   '3-04-401-01_38.tif',
#   '3-04-401-01_39.tif',
#   '3-04-401-01_40.tif',
#   '3-04-401-01_41.tif',
#   '3-04-401-01_42.tif',
#   '3-04-401-01_43.tif',
#   '3-04-401-01_44.tif',
#   '3-04-401-01_45.tif',
#   '3-04-401-01_46.tif',
#   '3-04-401-01_47.tif',
#   '3-04-401-01_48.tif',
#   '3-04-401-01_49.tif',
#   '3-04-401-01_50.tif',
#   '3-04-401-01_51.tif',
#   '3-04-401-01_52.tif',
#   '3-04-401-01_53.tif',
#   '3-04-401-01_54.tif',
#   '3-04-401-01_55.tif',
#   '3-04-401-01_56.tif',
#   '3-04-401-01_57.tif',
#   '3-04-401-01_58.tif',
#   '3-04-401-01_59.tif',
#   '3-04-401-01_60.tif',
#   '3-04-401-01_61.tif',
#   '3-04-401-01_62.tif',
#   '3-04-401-01_63.tif',
#   '3-04-401-01_64.tif',
#   '3-04-401-01_65.tif',
#   '3-04-401-01_66.tif',
#   '3-04-401-01_67.tif',
#   '3-04-401-01_68.tif',
#   '3-04-401-01_69.tif',
#   '3-04-401-01_70.tif',
#   '3-04-401-01_71.tif',
#   '3-04-401-01_72.tif',
#   '3-04-401-01_73.tif',
#   '3-04-401-01_74.tif',
#   '3-04-401-01_75.tif',
#   'musannah planned_25.png',
#   'musannah planned_26.png',
#   'musannah planned_27.png',
#   'musannah planned_28.png',
#   'musannah planned_29.png',
#   'musannah planned_30.png',
#   'musannah planned_31.png',
#   'musannah planned_32.png',
#   'musannah planned_33.png',
#   'musannah planned_34.png',
#   'musannah planned_35.png',
#   'musannah planned_36.png',
#   'musannah planned_37.png',
#   'musannah planned_38.png',
#   'musannah planned_39.png',
#   'musannah planned_40.png',
#   'musannah planned_41.png',
#   'musannah planned_42.png',
#   'musannah planned_43.png',
#   'musannah_66.png',
#   'Scanned20 (2)_2.png',
#   'Scanned21_5.png',
#   'Scanned26_21.png',
#   'Scanned31_131.png',
#   'Scanned31_132.png',
#   'Scanned31_133.png',
#   'Scanned31_134.png',
#   'Scanned31_135.png',
#   'Scanned31_136.png',
#   'Scanned31_137.png',
#   'Scanned31_138.png',
#   'Scanned31_139.png',
#   'Scanned31_140.png',
#   'Scanned31_141.png',
#   'Scanned31_142.png',
#   'Scanned31_143.png',
#   'Scanned31_144.png',
#   'Scanned31_145.png',
#   'Scanned31_146.png',
#   'Scanned31_147.png',
#   'Scanned36_0.png'],
#  ['./Image test/0_28.png',
#   './Image test/3-04-378-01_03.tif',
#   './Image test/3-04-378-01_04.tif',
#   './Image test/3-04-378-01_05.tif',
#   './Image test/3-04-378-01_06.tif',
#   './Image test/3-04-378-01_07.tif',
#   './Image test/3-04-378-01_08.tif',
#   './Image test/3-04-378-01_09.tif',
#   './Image test/3-04-378-01_10.tif',
#   './Image test/3-04-378-01_11.tif',
#   './Image test/3-04-378-01_12.tif',
#   './Image test/3-04-378-01_13.tif',
#   './Image test/3-04-378-01_14.tif',
#   './Image test/3-04-378-01_15.tif',
#   './Image test/3-04-378-01_16.tif',
#   './Image test/3-04-378-01_17.tif',
#   './Image test/3-04-378-01_18.tif',
#   './Image test/3-04-378-01_19.tif',
#   './Image test/3-04-378-01_20.tif',
#   './Image test/3-04-378-01_21.tif',
#   './Image test/3-04-378-01_22.tif',
#   './Image test/3-04-378-01_23.tif',
#   './Image test/3-04-378-01_24.tif',
#   './Image test/3-04-378-01_25.tif',
#   './Image test/3-04-378-01_26.tif',
#   './Image test/3-04-378-01_27.tif',
#   './Image test/3-04-378-01_28.tif',
#   './Image test/3-04-378-01_29.tif',
#   './Image test/3-04-378-01_30.tif',
#   './Image test/3-04-378-01_31.tif',
#   './Image test/3-04-378-01_32.tif',
#   './Image test/3-04-378-01_33.tif',
#   './Image test/3-04-378-01_34.tif',
#   './Image test/3-04-378-01_35.tif',
#   './Image test/3-04-378-01_36.tif',
#   './Image test/3-04-378-01_37.tif',
#   './Image test/3-04-378-01_38.tif',
#   './Image test/3-04-378-01_39.tif',
#   './Image test/3-04-378-01_40.tif',
#   './Image test/3-04-378-01_41.tif',
#   './Image test/3-04-378-01_42.tif',
#   './Image test/3-04-378-01_43.tif',
#   './Image test/3-04-378-01_44.tif',
#   './Image test/3-04-378-01_45.tif',
#   './Image test/3-04-378-01_46.tif',
#   './Image test/3-04-378-01_47.tif',
#   './Image test/3-04-378-01_48.tif',
#   './Image test/3-04-378-01_49.tif',
#   './Image test/3-04-378-01_50.tif',
#   './Image test/3-04-378-01_51.tif',
#   './Image test/3-04-378-01_52.tif',
#   './Image test/3-04-378-01_53.tif',
#   './Image test/3-04-378-01_54.tif',
#   './Image test/3-04-378-01_55.tif',
#   './Image test/3-04-378-01_56.tif',
#   './Image test/3-04-378-01_57.tif',
#   './Image test/3-04-378-01_58.tif',
#   './Image test/3-04-378-01_59.tif',
#   './Image test/3-04-378-01_60.tif',
#   './Image test/3-04-378-01_61.tif',
#   './Image test/3-04-378-01_62.tif',
#   './Image test/3-04-378-01_63.tif',
#   './Image test/3-04-378-01_64.tif',
#   './Image test/3-04-378-01_65.tif',
#   './Image test/3-04-378-01_66.tif',
#   './Image test/3-04-378-01_67.tif',
#   './Image test/3-04-378-01_68.tif',
#   './Image test/3-04-401-01_01.tif',
#   './Image test/3-04-401-01_02.tif',
#   './Image test/3-04-401-01_03.tif',
#   './Image test/3-04-401-01_04.tif',
#   './Image test/3-04-401-01_05.tif',
#   './Image test/3-04-401-01_06.tif',
#   './Image test/3-04-401-01_07.tif',
#   './Image test/3-04-401-01_08.tif',
#   './Image test/3-04-401-01_09.tif',
#   './Image test/3-04-401-01_10.tif',
#   './Image test/3-04-401-01_11.tif',
#   './Image test/3-04-401-01_12.tif',
#   './Image test/3-04-401-01_13.tif',
#   './Image test/3-04-401-01_14.tif',
#   './Image test/3-04-401-01_15.tif',
#   './Image test/3-04-401-01_16.tif',
#   './Image test/3-04-401-01_17.tif',
#   './Image test/3-04-401-01_18.tif',
#   './Image test/3-04-401-01_19.tif',
#   './Image test/3-04-401-01_20.tif',
#   './Image test/3-04-401-01_21.tif',
#   './Image test/3-04-401-01_22.tif',
#   './Image test/3-04-401-01_23.tif',
#   './Image test/3-04-401-01_24.tif',
#   './Image test/3-04-401-01_25.tif',
#   './Image test/3-04-401-01_26.tif',
#   './Image test/3-04-401-01_27.tif',
#   './Image test/3-04-401-01_28.tif',
#   './Image test/3-04-401-01_29.tif',
#   './Image test/3-04-401-01_30.tif',
#   './Image test/3-04-401-01_31.tif',
#   './Image test/3-04-401-01_32.tif',
#   './Image test/3-04-401-01_33.tif',
#   './Image test/3-04-401-01_34.tif',
#   './Image test/3-04-401-01_35.tif',
#   './Image test/3-04-401-01_36.tif',
#   './Image test/3-04-401-01_37.tif',
#   './Image test/3-04-401-01_38.tif',
#   './Image test/3-04-401-01_39.tif',
#   './Image test/3-04-401-01_40.tif',
#   './Image test/3-04-401-01_41.tif',
#   './Image test/3-04-401-01_42.tif',
#   './Image test/3-04-401-01_43.tif',
#   './Image test/3-04-401-01_44.tif',
#   './Image test/3-04-401-01_45.tif',
#   './Image test/3-04-401-01_46.tif',
#   './Image test/3-04-401-01_47.tif',
#   './Image test/3-04-401-01_48.tif',
#   './Image test/3-04-401-01_49.tif',
#   './Image test/3-04-401-01_50.tif',
#   './Image test/3-04-401-01_51.tif',
#   './Image test/3-04-401-01_52.tif',
#   './Image test/3-04-401-01_53.tif',
#   './Image test/3-04-401-01_54.tif',
#   './Image test/3-04-401-01_55.tif',
#   './Image test/3-04-401-01_56.tif',
#   './Image test/3-04-401-01_57.tif',
#   './Image test/3-04-401-01_58.tif',
#   './Image test/3-04-401-01_59.tif',
#   './Image test/3-04-401-01_60.tif',
#   './Image test/3-04-401-01_61.tif',
#   './Image test/3-04-401-01_62.tif',
#   './Image test/3-04-401-01_63.tif',
#   './Image test/3-04-401-01_64.tif',
#   './Image test/3-04-401-01_65.tif',
#   './Image test/3-04-401-01_66.tif',
#   './Image test/3-04-401-01_67.tif',
#   './Image test/3-04-401-01_68.tif',
#   './Image test/3-04-401-01_69.tif',
#   './Image test/3-04-401-01_70.tif',
#   './Image test/3-04-401-01_71.tif',
#   './Image test/3-04-401-01_72.tif',
#   './Image test/3-04-401-01_73.tif',
#   './Image test/3-04-401-01_74.tif',
#   './Image test/3-04-401-01_75.tif',
#   './Image test/musannah planned_25.png',
#   './Image test/musannah planned_26.png',
#   './Image test/musannah planned_27.png',
#   './Image test/musannah planned_28.png',
#   './Image test/musannah planned_29.png',
#   './Image test/musannah planned_30.png',
#   './Image test/musannah planned_31.png',
#   './Image test/musannah planned_32.png',
#   './Image test/musannah planned_33.png',
#   './Image test/musannah planned_34.png',
#   './Image test/musannah planned_35.png',
#   './Image test/musannah planned_36.png',
#   './Image test/musannah planned_37.png',
#   './Image test/musannah planned_38.png',
#   './Image test/musannah planned_39.png',
#   './Image test/musannah planned_40.png',
#   './Image test/musannah planned_41.png',
#   './Image test/musannah planned_42.png',
#   './Image test/musannah planned_43.png',
#   './Image test/musannah_66.png',
#   './Image test/Scanned20 (2)_2.png',
#   './Image test/Scanned21_5.png',
#   './Image test/Scanned26_21.png',
#   './Image test/Scanned31_131.png',
#   './Image test/Scanned31_132.png',
#   './Image test/Scanned31_133.png',
#   './Image test/Scanned31_134.png',
#   './Image test/Scanned31_135.png',
#   './Image test/Scanned31_136.png',
#   './Image test/Scanned31_137.png',
#   './Image test/Scanned31_138.png',
#   './Image test/Scanned31_139.png',
#   './Image test/Scanned31_140.png',
#   './Image test/Scanned31_141.png',
#   './Image test/Scanned31_142.png',
#   './Image test/Scanned31_143.png',
#   './Image test/Scanned31_144.png',
#   './Image test/Scanned31_145.png',
#   './Image test/Scanned31_146.png',
#   './Image test/Scanned31_147.png',
#   './Image test/Scanned36_0.png'])

# %%
import pytesseract as tess
import datetime
import re

tess.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %% [markdown]
# #### use above "USABLE_IMAGES" folder as input path below

# %%
input_path = "USABLE_IMAGES_TEST/"
logfile_path = "LOGFILE_TEST_1/"
output_path = "OUTPUT_TESt1/"

try:
    os.mkdir(output_path)
    print("Output File: {:s} has been created".format(output_path))
except FileExistsError:
    print("File Already Exists...!")

try:
    os.mkdir(logfile_path)
    print("Output File: {:s} has been created".format(logfile_path))
except FileExistsError:
    print("File Already Exists...!")
# Out:
# Output File: OUTPUT_TESt1/ has been created
# Output File: LOGFILE_TEST_1/ has been created

# %%
imglist = os.listdir(input_path)
imageList = [(lambda x: input_path +x)(x) for x in imglist]

# %%
logfile = open(logfile_path + "logfile.txt", 'w+')
logfile.write("Name,path,date,time\n")
all_list = []

print("################# OCR STARTED #######################################")

for i in range(len(imageList)):

    word_list = []
    name = imglist[i].split(".")[0]
    serial_number = "Serial Number = Not Recognized!"
    img = cv2.imread(imageList[i])
    
    img = cv2.resize(img,None,fx=0.5, fy= 0.5)
    #converting into grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    #Putting the threshold
    adaptive_threshold = cv2.adaptiveThreshold(gray,255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,85,11)
    #config="--psm 3"
    text = tess.image_to_string(adaptive_threshold,lang='eng')#config=config
    
#     text = tess.image_to_string(img)
    t = text.replace('\r', ' ')
    text_line = t.splitlines()

    start = 100
    end = None

    for line in range(len(text_line)):
        word = text_line[line]
        word_split = word.split("-")

        if "EASTING" in word or "LINE" in word or "NORTHING" in word or "DIST" in word:
            if start > line:
                start = line

        if "AREA=" in word or "AREA =" in word:
            end = line
            REAL = word.split(" ")[0:5]
            separator = ' '
            separator.join(REAL)
            word_list.append(separator.join(REAL))

            if start == None:
                for te in range(len(text_line)):
                    try:
                        if len(str(int(float(text_line[te].split(" ")[0])))) == 6:
                            #                             word_list.append(text_line[te:line])
                            start = te
                            break
                    except:
                        continue

        if len(word_split) == 5:
            s_split = word.split("-")
            s_last = s_split[-1].split(" ")[0]
            serial_number = ""
            for s in s_split[:-1]:
                serial_number+=s
                serial_number+="-"
            serial_number+=s_last
            serial_number = "Serial Number = {:s}".format(serial_number)

    word_list.insert(0, serial_number)

    separator = '\r'
    #     separator.join(all_list[2][2:])
    if (start != 100) and (end != None):
        #         print(separator.join(text_line[start:end]))
        word_list.extend(text_line[start:end])
    #         print(start, " and ", end)
    separator = '\n'

    file_name = output_path + name + ".txt"
    path = os.path.abspath(file_name)

    time = datetime.datetime.now().strftime("%d%m%Y, %H:%M%p")

    logfile.write(name + "," + path + "," + time + "\n\n")

    file = open(file_name, 'w+')

    print("{:s} : {:d} out of {:d} created..".format(path, i + 1, len(imageList)))

    try:
        file.write(separator.join(word_list))
    except:
        file.write(word_list)
    #     file.write(separator.join(word_list))
    file.close()
    #     print(word_list)
    all_list.append(word_list)
logfile.close()

print("################# OCR END #######################################")
# Out:
# ################# OCR STARTED #######################################
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\0_28.txt : 1 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_03.txt : 2 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_04.txt : 3 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_05.txt : 4 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_06.txt : 5 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_07.txt : 6 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_08.txt : 7 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_09.txt : 8 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_10.txt : 9 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_11.txt : 10 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_12.txt : 11 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_13.txt : 12 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_14.txt : 13 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_15.txt : 14 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_16.txt : 15 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_17.txt : 16 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_18.txt : 17 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_19.txt : 18 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_20.txt : 19 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_21.txt : 20 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_22.txt : 21 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_23.txt : 22 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_24.txt : 23 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_25.txt : 24 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_26.txt : 25 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_27.txt : 26 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_28.txt : 27 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_29.txt : 28 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_30.txt : 29 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_31.txt : 30 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_32.txt : 31 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_33.txt : 32 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_34.txt : 33 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_35.txt : 34 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_36.txt : 35 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_37.txt : 36 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_38.txt : 37 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_39.txt : 38 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_40.txt : 39 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_41.txt : 40 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_42.txt : 41 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_43.txt : 42 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_44.txt : 43 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_45.txt : 44 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_46.txt : 45 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_47.txt : 46 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_48.txt : 47 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_49.txt : 48 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_50.txt : 49 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_51.txt : 50 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_52.txt : 51 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_53.txt : 52 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_54.txt : 53 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_55.txt : 54 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_56.txt : 55 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_57.txt : 56 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_58.txt : 57 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_59.txt : 58 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_60.txt : 59 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_61.txt : 60 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_62.txt : 61 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_63.txt : 62 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_64.txt : 63 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_65.txt : 64 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_66.txt : 65 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_67.txt : 66 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-378-01_68.txt : 67 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-401-01_01.txt : 68 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-401-01_02.txt : 69 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-401-01_03.txt : 70 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-401-01_04.txt : 71 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-401-01_05.txt : 72 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-401-01_06.txt : 73 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-401-01_07.txt : 74 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-401-01_08.txt : 75 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-401-01_09.txt : 76 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-401-01_10.txt : 77 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-401-01_11.txt : 78 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-401-01_12.txt : 79 out of 183 created..
# C:\Users\PC\Desktop\Fiverr_Update\OCR\OCR_From_Image\Deliver\OUTPUT_TESt1\3-04-401-01_13.txt : 80 out of 183 created..
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-f72b20fbf02c> in <module>
#      79     logfile.write(name + "," + path + "," + time + "\n\n")
#      80
# ---> 81     file = open(file_name, 'w+')
#      82
#      83     print("{:s} : {:d} out of {:d} created..".format(path, i + 1, len(imageList)))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'OUTPUT_TESt1/3-04-401-01_14.txt'
